# %%
import pandas as pd

# %%
# df = pd.read_json("all/raw_data1.json")
# df1 = pd.read_json("all/raw_data2.json")
# df2 = pd.read_json("all/raw_data3.json")
# df3 = pd.read_json("all/raw_data4.json")
# df4 = pd.read_json("all/raw_data5.json")
# df5 = pd.read_json("all/raw_data6.json")
# df6 = pd.read_json("all/raw_data7.json")
# df7 = pd.read_json("all/raw_data8.json")
# dfi = pd.concat([df, df1, df2, df3, df4, df5, df6, df7])

dfi = pd.read_json("all/raw_data2.json")

# %%
dfi.head()
# Out:
#   agebracket                                 backupnotes  \
# 0         20                          Student from Wuhan
# 1                                     Student from Wuhan
# 2                                     Student from Wuhan
# 3         45         Travel history to Italy and Austria
# 4         24  Travel history to Dubai, Singapore contact
#
#   contractedfromwhichpatientsuspected currentstatus dateannounced  \
# 0                                         Recovered    30/01/2020
# 1                                         Recovered    02/02/2020
# 2                                         Recovered    03/02/2020
# 3                                         Recovered    02/03/2020
# 4                                         Recovered    02/03/2020
#
#                detectedcity detecteddistrict detectedstate estimatedonsetdate  \
# 0                  Thrissur         Thrissur        Kerala
# 1                 Alappuzha        Alappuzha        Kerala
# ...

# %%
df_k = dfi[dfi['detectedstate'] == "Maharashtra"]
# df_k = dfi
df_k['patientnumber'] = 'P' + df_k['patientnumber'].astype(str)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_k1 = df_k.drop(['detectedstate', 'source1', 'source2', 'source3', 'statecode', 'statepatientnumber', 'statuschangedate', 'numcases'], axis =1 )

# %%
df_k1.head()
# Out:
#    agebracket                                        backupnotes  \
# 43                Returned from Dubai on 1 March, Husband of P45
# 44                   Returned from Dubai on 1 March, Wife of P44
# 59          3                              Daughter of P44 & P45
# 60             Co-passenger with P44 & P45 in cab of P62 from...
# 61             Cab driver who ferried P44, P45, P61 from Mumb...
#
#    contractedfromwhichpatientsuspected currentstatus dateannounced  \
# 43                                         Recovered    09/03/2020
# 44                                         Recovered    09/03/2020
# 59                            P44, P45  Hospitalized    10/03/2020
# 60                            P44, P45  Hospitalized    10/03/2020
# 61                            P44, P45  Hospitalized    10/03/2020
#
#    detectedcity detecteddistrict estimatedonsetdate gender nationality  \
# 43         Pune             Pune                         M       India
# ...

# %%
df_k1.to_json("raw_data_all.json", orient='records')

# %%
dfi.head()
# Out:
#   agebracket                                 backupnotes  \
# 0         20                          Student from Wuhan
# 1                                     Student from Wuhan
# 2                                     Student from Wuhan
# 3         45         Travel history to Italy and Austria
# 4         24  Travel history to Dubai, Singapore contact
#
#   contractedfromwhichpatientsuspected currentstatus dateannounced  \
# 0                                         Recovered    30/01/2020
# 1                                         Recovered    02/02/2020
# 2                                         Recovered    03/02/2020
# 3                                         Recovered    02/03/2020
# 4                                         Recovered    02/03/2020
#
#                detectedcity detecteddistrict detectedstate estimatedonsetdate  \
# 0                  Thrissur         Thrissur        Kerala
# 1                 Alappuzha        Alappuzha        Kerala
# ...
